# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.yaml")  # build a new model from YAML
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
# Out:
# Transferred 499/499 items from pretrained weights
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.yaml")  # build a new model from YAML
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="../datasets/ue5_yolo_dataset/data.yaml", epochs=3)
# Out:
# Transferred 499/499 items from pretrained weights
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# ...

# %% [markdown]
# 开始修改模型：
# 先跑通，后修改
# <br><br>
# yolov8,yolov11,yolov12,修改之后的yolo
# <br><br>
# 不同大小的分辨率，修改之后的yolo选用大分辨率做设计

# %% [markdown]
# 基于rtx4090

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolo11n.yaml")  # build a new model from YAML
# model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="../datasets/ue5_yolo_dataset/data.yaml", epochs=3)
# Out:
# Transferred 499/499 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.3.241 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="../datasets/ue5_yolo_dataset/data.yaml", epochs=3, imgsz=1280)
# Out:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# New https://pypi.org/project/ultralytics/8.3.241 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %% [markdown]
# 基于5060

# %%
# yolov8n.pt imgsz=480 epochs=50
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# print("model.task =", model.task)
# print("overrides task =", model.overrides.get("task"))
# # Display model information (optional)
# model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="../datasets/ue5_yolo_dataset/data.yaml", epochs=1)
# Out:
# New https://pypi.org/project/ultralytics/8.3.241 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# ...

# %% [markdown]
# 添加模块

# %%
from ultralytics import YOLO


# 1. 并非加载预训练模型（这里用 YOLO11n，也可以换成 yolov11s、best.pt 等）
#    而是让YAML 定义自己的网络结构
model = YOLO(model="/home/flash/workspace/vision/ultralytics/ultralytics/cfg/models/11/yolo11n-ufnonet.yaml")
# print(model.info())
# model.predict(source="https://ultralytics.com/images/bus.jpg", save=True)  # 测试预测
# 2. 开始训练
model.train(
    data="../datasets/ue5_yolo_dataset/data.yaml",  # 数据集配置文件
    # pretrained="/home/flash/workspace/vision/ultralytics/examples/ue_drone/tests/yolo11n.pt",  # 预训练权重
    epochs=1,        # 训练轮数（建议 100+）
    imgsz=640,         # 输入图片大小
    batch=16,          # batch size
    amp=False,          # 是否使用混合精度训练
    exist_ok=True,     # 覆盖已存在的结果
    # verbose=True       # 打印详细训练日志
)

# 3. 训练完成后验证模型
# metrics = model.val()
# print("验证结果：", metrics)

# 4. 可选：导出为 ONNX/TorchScript 等格式
# model.export(format="onnx")
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# ...

# %%
from ultralytics.nn import modules
print('MyConv' in dir(modules))
# Out:
# True

# %% [markdown]
# 测试模块输入输出的shape是否一致

# %%
import torch
import torch.nn as nn
import numpy as np
def autopad(k, p=None, d=1):  # kernel, padding, dilation
    """Pad to 'same' shape outputs."""
    if d > 1:
        k = d * (k - 1) + 1 if isinstance(k, int) else [d * (x - 1) + 1 for x in k]  # actual kernel-size
    if p is None:
        p = k // 2 if isinstance(k, int) else [x // 2 for x in k]  # auto-pad
    return p
class Conv(nn.Module):
    """Standard convolution module with batch normalization and activation.

    Attributes:
        conv (nn.Conv2d): Convolutional layer.
        bn (nn.BatchNorm2d): Batch normalization layer.
        act (nn.Module): Activation function layer.
        default_act (nn.Module): Default activation function (SiLU).
    """

    default_act = nn.SiLU()  # default activation

    def __init__(self, c1, c2, k=1, s=1, p=None, g=1, d=1, act=True):
        """Initialize Conv layer with given parameters.

        Args:
            c1 (int): Number of input channels.
            c2 (int): Number of output channels.
            k (int): Kernel size.
            s (int): Stride.
            p (int, optional): Padding.
            g (int): Groups.
            d (int): Dilation.
            act (bool | nn.Module): Activation function.
        """
        super().__init__()
        self.conv = nn.Conv2d(c1, c2, k, s, autopad(k, p, d), groups=g, dilation=d, bias=False)
        self.bn = nn.BatchNorm2d(c2)
        self.act = self.default_act if act is True else act if isinstance(act, nn.Module) else nn.Identity()

    def forward(self, x):
        """Apply convolution, batch normalization and activation to input tensor.

        Args:
            x (torch.Tensor): Input tensor.

        Returns:
            (torch.Tensor): Output tensor.
        """
        return self.act(self.bn(self.conv(x)))

    def forward_fuse(self, x):
        """Apply convolution and activation without batch normalization.

        Args:
            x (torch.Tensor): Input tensor.

        Returns:
            (torch.Tensor): Output tensor.
        """
        return self.act(self.conv(x))

test_model = Conv(3, 64, k=3, s=1)
X = np.random.randn(1, 3, 640, 640).astype(np.float32)
y = test_model(torch.tensor(X))
print(y.shape)
# Out:
# torch.Size([1, 64, 640, 640])

# %%
from ultralytics.nn.modules import C3k2
test_model = C3k2(c1=3, c2=64, n=2, c3k=False, e=1, )
X = np.random.randn(1, 3, 640, 640).astype(np.float32)
y = test_model(torch.tensor(X))
print(y.shape)
# Out:
# torch.Size([1, 64, 640, 640])

# %%
import torch
import numpy as np
from ultralytics.nn.modules import UFNO
test_model = UFNO(modes1=16, modes2=16, width=3, width2=32)
X = np.random.randn(1, 3, 640, 640).astype(np.float32)
y = test_model(torch.tensor(X))
print(y.shape)
# Out:
# torch.Size([1, 32, 640, 640])
